# %% [markdown]
# # Root Simulator Module

# %%
import sys
sys.path.append('/home/johnsalako/Desktop/cmse802/root_variability_simulator/root_simulator')

# %% [markdown]
# Import root_simulator module

# %%
from root_simulator import RootSimulator

# %% [markdown]
# ### Create an instance of the class.

# %%
simulate_root = RootSimulator()

# %% [markdown]
# #### Create the geometry including the feature distribution within the layer.

# %%
# Declaring variables
lateral = [50, -50]  # starts from -50 and extend to 50 on the x-axis
depth = -50  # Depth to be investigated including some boundary.
layer = [-1, -20] # The layer containing the roots.

# The geolocation of points in the tree distribution.
tree_distr = [(-10, -1), (-10, -2.5), (-19, -10), (-22, -17), (-17.7, -11.2), (-12, -7),
           (-13.7, -10), (-16, -12), (-18, -18), (-15, -15), (-10, -12), (-9, -17),
           (-7, -12), (-7, -7), (-5, -12), (-3, -17), (-1, -12), (0, -9), (8, -17),
           (2, -10), (10, -12), (12, -15), (15, -17), (12, -10), (5, -8), (9.3, -6),
           (17, -8), (25, -14), (16, -6), (5, -3), (5, -1)]

# %%
simulate_root.create_geom(lateral, depth, layer, tree_distr)
# Out:
# Mesh: Nodes: 132 Cells: 0 Boundaries: 135

# %%
simulate_root.display_geometry()
# Out:
# (<AxesSubplot:>, None)

# %% [markdown]
# #### Create the mesh and display the mesh

# %% [markdown]
# You can perform several sensitivity test by changing 'wa' to any one of these ['dd', 'wb', 'pp', 'slm', 'pd'] and running the cells again

# %%
simulate_root.create_mesh('dd')
# Out:
# Mesh: Nodes: 3053 Cells: 5781 Boundaries: 8833

# %%
simulate_root.display_mesh()
# Out:
# (<AxesSubplot:>, None)

# %% [markdown]
# ### Add resistivity to the regions as seen in the geometry.

# %% [markdown]
# There are four regional makers representing areas of varying resistivity.

# %%
res_tree = [[1, 100], [2, 75], [3, 50], [4, 150]]  # Made the root higher.

# Resistivity typically will decline below the top layer of the soil because
# of soil moisture --- The higher the water content the lower the resistivity.

# %%
simulate_root.plot_rhomap(res_tree)
# Out:
# (<AxesSubplot:>, <matplotlib.colorbar.Colorbar at 0x7fa32a34df90>)

# %% [markdown]
# #### Run the forward Inversion to see display the Apparent Resistivity.

# %%
simulate_root.forward_model(res_tree)
# Out:
# 21/04/22 - 11:07:45 - pyGIMLi - INFO - Calculate geometric factors.
# ModellingBase::setMesh() copying new mesh ... Found datafile: 21 electrodes
# Found: 21 free-electrodes
# rMin = 1.5, rMax = 120
# NGauLeg + NGauLag for inverse Fouriertransformation: 11 + 4
# Found non-Neumann domain
# 0.225 s
# FOP updating mesh dependencies ... 0 s
# 21/04/22 - 11:07:46 - pyGIMLi - INFO - Filtered rhoa (min/max) 56.725351656227204 158.76875658553487
# relativeError set to a value > 0.5 .. assuming this is a percentage Error level dividing them by 100
# Data error estimate (min:max)  0.010000430909750916 : 0.01112299104639737
# Obtaining geometric factors (analytical)
# Calculating response for model: min = 50 max = 150
# Allocating memory for primary potential...... 0.029
#
# No primary potential for secondary field calculation. Calculating analytically...
# Factorize (Cholmod) matrix ... 0.037
# Factorize (Cholmod) matrix ... 0.019
# Factorize (Cholmod) matrix ... 0.019
# Factorize (Cholmod) matrix ... 0.017
# Factorize (Cholmod) matrix ... 0.019
# Factorize (Cholmod) matrix ... 0.02
# Factorize (Cholmod) matrix ... 0.023
# Factorize (Cholmod) matrix ... 0.03
# Factorize (Cholmod) matrix ... 0.049
# Factorize (Cholmod) matrix ... 0.025
# Factorize (Cholmod) matrix ... 0.028
# Factorize (Cholmod) matrix ... 0.027
# Factorize (Cholmod) matrix ... 0.028
# Factorize (Cholmod) matrix ... 0.024
# Factorize (Cholmod) matrix ... 0.026
# Forward: time: 0.723s
# Response: min = 57.4042 max = 160.369 mean = 95.4651
# Reciprocity rms(modelReciprocity) 0.0922183%, max: 0.214523%
# (<AxesSubplot:>, <matplotlib.colorbar.Colorbar at 0x7fa32c643010>)

# %% [markdown]
# #### Perform the Inversion to Output the True Resistivity

# %%
simulate_root.inversion2d()
# Out:
# 21/04/22 - 11:07:54 - pyGIMLi - INFO - Found 2 regions.
# 21/04/22 - 11:07:54 - pyGIMLi - INFO - Region with smallest marker (1) set to background
# 21/04/22 - 11:07:54 - Core - WARNING - Region Nr: 1  is background and should not get a model transformation.
# 21/04/22 - 11:07:54 - Core - WARNING - Region Nr: 1  is background and should not get a model control.
# 21/04/22 - 11:07:54 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 21/04/22 - 11:07:54 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 21/04/22 - 11:07:54 - pyGIMLi - INFO - Use median(data values)=93.39325180905615
# 21/04/22 - 11:07:54 - pyGIMLi - INFO - Created startmodel from forward operator: 311 [93.39325180905615,...,93.39325180905615]
# 21/04/22 - 11:07:54 - pyGIMLi - INFO - Starting inversion.
# Constructing Delaunay triangulation by divide-and-conquer method.
# Delaunay milliseconds:  0
# Recovering segments in Delaunay triangulation.
# Segment milliseconds:  0
# Removing unwanted triangles.
# Spreading regional attributes and area constraints.
# Hole milliseconds:  0
# Adding Steiner points to enforce quality.
# Quality milliseconds:  0
#
# Writing vertices.
# Writing triangles.
# Writing segments.
# Writing edges.
#
# Output milliseconds:  0
# Total running milliseconds:  0
#
# Statistics:
#
#   Input vertices: 49
#   Input segments: 50
#   Input holes: 0
#
#   Mesh vertices: 265
#   Mesh triangles: 460
#   Mesh edges: 724
#   Mesh exterior boundary edges: 68
#   Mesh interior boundary edges: 16
#   Mesh subsegments (constrained edges): 84
#
# min/max(dweight) = 89.9039/99.9957
# fop: <pygimli.physics.ert.ertModelling.ERTModelling object at 0x7fa32c7959e0>
# Data transformation: <pgcore._pygimli_.RTransLogLU object at 0x7fa32c695940>
# Model transformation: <pgcore._pygimli_.RTransLog object at 0x7fa32c694400>
# min/max (data): 56.73/159
# min/max (error): 1%/1.11%
# min/max (start model): 93.39/93.39
# --------------------------------------------------------------------------------
# Calculating response for model: min = 93.3933 max = 93.3933
# Allocating memory for primary potential...... 0
#
# No primary potential for secondary field calculation. Calculating analytically...
# Factorize (Cholmod) matrix ... 0.007
# Factorize (Cholmod) matrix ... 0.007
# Factorize (Cholmod) matrix ... 0.007
# Factorize (Cholmod) matrix ... 0.008
# Factorize (Cholmod) matrix ... 0.007
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.008
# Factorize (Cholmod) matrix ... 0.007
# Factorize (Cholmod) matrix ... 0.007
# Factorize (Cholmod) matrix ... 0.007
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.008
# Factorize (Cholmod) matrix ... 0.007
# Factorize (Cholmod) matrix ... 0.006
# Forward: time: 0.157s
# Response: min = 93.1158 max = 93.5148 mean = 93.3304
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# min/max(dweight) = 89.9039/99.9957
# Building constraints matrix
# constraint matrix of size(nBounds x nModel) 436 x 311
# check Jacobian: wrong dimensions: (0x0) should be (171x311)  force: 1
# jacobian size invalid, forced recalc: 1
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(6/6-std::mt): 0.002:time: 0.129s
# sens sum: median = 1.04783 min = 0.958801 max = 1.37268
# ... 0.13 s
# min data = 56.7254 max data = 158.769 (171)
# min error = 0.0100004 max error = 0.011123 (171)
# min response = 93.1158 max response = 93.5148 (171)
# calc without reference model
# 0: rms/rrms(data, response) = 22.4901/24.5105%
# 0: chi^2(data, response, error, log) = 529.721
# 0: Phi = 90582.2 + 0 * 20 = 90582.2
# Iter: 0
# solve CGLSCDWWtrans with lambda = 20
# --------------------------------------------------------------------------------
# inv.iter 2 ... Calculating response for model: min = 48.7428 max = 168.654
# Using existing primary potentials.
# Factorize (Cholmod) matrix ... 0.007
# Factorize (Cholmod) matrix ... 0.005
# Factorize (Cholmod) matrix ... 0.005
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.004
# Factorize (Cholmod) matrix ... 0.004
# Factorize (Cholmod) matrix ... 0.004
# Factorize (Cholmod) matrix ... 0.004
# Factorize (Cholmod) matrix ... 0.004
# Factorize (Cholmod) matrix ... 0.005
# Factorize (Cholmod) matrix ... 0.005
# Factorize (Cholmod) matrix ... 0.005
# Factorize (Cholmod) matrix ... 0.005
# Factorize (Cholmod) matrix ... 0.004
# Forward: time: 0.101s
# Response: min = 63.6793 max = 157.996 mean = 95.5607
# Reciprocity rms(modelReciprocity) 0.227816%, max: 0.562399%
# Linesearch tau = 1
# 1: Model: min = 48.7428; max = 168.654
# 1: Response: min = 63.6597; max = 158.014
# 1: rms/rrms(data, Response) = 2.36016/2.85844%
# 1: chi^2(data, Response, error, log) = 7.19478
# 1: Phi = 1230.31+3.74897*20=1305.29
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(6/6-std::mt): 0:time: 0.058s
# sens sum: median = 1.11896 min = 0.965884 max = 1.35223
# ... 0.059 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 46.2525 max = 180.671
# Using existing primary potentials.
# Factorize (Cholmod) matrix ... 0.007
# Factorize (Cholmod) matrix ... 0.005
# Factorize (Cholmod) matrix ... 0.004
# Factorize (Cholmod) matrix ... 0.004
# Factorize (Cholmod) matrix ... 0.005
# Factorize (Cholmod) matrix ... 0.004
# Factorize (Cholmod) matrix ... 0.003
# Factorize (Cholmod) matrix ... 0.004
# Factorize (Cholmod) matrix ... 0.004
# Factorize (Cholmod) matrix ... 0.004
# Factorize (Cholmod) matrix ... 0.004
# Factorize (Cholmod) matrix ... 0.004
# Factorize (Cholmod) matrix ... 0.004
# Factorize (Cholmod) matrix ... 0.004
# Factorize (Cholmod) matrix ... 0.003
# Forward: time: 0.088s
# Response: min = 57.6259 max = 159.405 mean = 95.495
# Reciprocity rms(modelReciprocity) 0.214001%, max: 0.608159%
# chi² = 0.63 (dPhi = 85.37%) lam: 20.0
# Linesearch tau = 1
# 2: Model: min = 46.2525; max = 180.671
# 2: Response: min = 57.6257; max = 159.354
# 2: rms/rrms(data, Response) = 0.765524/0.808042%
# 2: chi^2(data, Response, error, log) = 0.629747
# 2: Phi = 107.687+4.16628*20=191.012
#
#
# ################################################################################
# #                  Abort criterion reached: chi² <= 1 (0.63)                   #
# ################################################################################
# 21/04/22 - 11:07:56 - pyGIMLi - INFO - Found 2 regions.
# 21/04/22 - 11:07:56 - pyGIMLi - INFO - Region with smallest marker (1) set to background
# 21/04/22 - 11:07:56 - Core - WARNING - Region Nr: 1  is background and should not get a model transformation.
# 21/04/22 - 11:07:56 - Core - WARNING - Region Nr: 1  is background and should not get a model control.
# 21/04/22 - 11:07:56 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 21/04/22 - 11:07:56 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 21/04/22 - 11:07:56 - pyGIMLi - INFO - Use median(data values)=93.39325180905615
# 21/04/22 - 11:07:56 - pyGIMLi - INFO - Created startmodel from forward operator: 160 [93.39325180905615,...,93.39325180905615]
# 21/04/22 - 11:07:56 - pyGIMLi - INFO - Starting inversion.
# Found datafile: 21 electrodes
# Found: 21 node-electrodes
# Found non-Neumann domain
#  updateDataDependency:: cleaning primpot
# Reset region parameter
# RegionManager copying mesh ...0.001 s
# create NeighborInfos ... 0 s
# analysing mesh ... 2 regions.
# creating para domain ... 0.002 s
# creating para domain ... 0.002 s
# ModellingBase::setMesh() copying new mesh ... Found datafile: 21 electrodes
# Found: 21 free-electrodes
# Found non-Neumann domain
# 0.011 s
# FOP updating mesh dependencies ... 0 s
# ModellingBase::setMesh() copying new mesh ... 0.01 s
# FOP updating mesh dependencies ... 0 s
# min/max(dweight) = 89.9039/99.9957
# fop: <pygimli.physics.ert.ertModelling.ERTModelling object at 0x7fa32c7959e0>
# Data transformation: <pgcore._pygimli_.RTransLogLU object at 0x7fa32c695940>
# Model transformation: <pgcore._pygimli_.RTransLog object at 0x7fa32c694400>
# min/max (data): 56.73/159
# min/max (error): 1%/1.11%
# min/max (start model): 93.39/93.39
# --------------------------------------------------------------------------------
# Calculating response for model: min = 93.3933 max = 93.3933
# Allocating memory for primary potential...... 0
#
# No primary potential for secondary field calculation. Calculating analytically...
# Factorize (Cholmod) matrix ... 0.01
# Factorize (Cholmod) matrix ... 0.007
# Factorize (Cholmod) matrix ... 0.007
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.005
# Factorize (Cholmod) matrix ... 0.007
# Factorize (Cholmod) matrix ... 0.007
# Factorize (Cholmod) matrix ... 0.007
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.009
# Factorize (Cholmod) matrix ... 0.007
# Factorize (Cholmod) matrix ... 0.007
# Factorize (Cholmod) matrix ... 0.006
# Forward: time: 0.161s
# Response: min = 92.8639 max = 99.2967 mean = 94.0452
# Reciprocity rms(modelReciprocity) 0.835476%, max: 3.19509%
# min/max(dweight) = 89.9039/99.9957
# Building constraints matrix
# constraint matrix of size(nBounds x nModel) 283 x 160
# check Jacobian: wrong dimensions: (171x311) should be (171x160)  force: 1
# jacobian size invalid, forced recalc: 1
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(6/6-std::mt): 0.001:time: 0.076s
# sens sum: median = 1.14855 min = 1.04829 max = 1.78987
# ... 0.084 s
# min data = 56.7254 max data = 158.769 (171)
# min error = 0.0100004 max error = 0.011123 (171)
# min response = 92.8639 max response = 99.2967 (171)
# calc without reference model
# 0: rms/rrms(data, response) = 22.4567/24.7249%
# 0: chi^2(data, response, error, log) = 531.103
# 0: Phi = 90818.6 + 0 * 20 = 90818.6
# Iter: 0
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 39.6823 max = 199.339
# Using existing primary potentials.
# Factorize (Cholmod) matrix ... 0.009
# Factorize (Cholmod) matrix ... 0.009
# Factorize (Cholmod) matrix ... 0.007
# Factorize (Cholmod) matrix ... 0.007
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.005
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.005
# Factorize (Cholmod) matrix ... 0.005
# Factorize (Cholmod) matrix ... 0.005
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.005
# Forward: time: 0.134s
# Response: min = 70.5965 max = 160.164 mean = 101.91
# Reciprocity rms(modelReciprocity) 5.98693%, max: 16.9859%
# 1: LS newModel: min = 39.6823; max = 199.339
# 1: LS newResponse: min = 70.9511; max = 153.401
# 1: rms/rrms(data, LS newResponse) = 13.2239/16.0119%
# 1: chi^2(data, LS newResponse, error, log) = 178.886
# 1: Phi = 30589.5+15--------------------------------------------------------------------------------
# inv.iter 2 ... .0733*20=30890.9
# Linesearch tau = 0.92
# Calculating response for model: min = 42.4946 max = 187.607
# Using existing primary potentials.
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.005
# Factorize (Cholmod) matrix ... 0.005
# Factorize (Cholmod) matrix ... 0.007
# Factorize (Cholmod) matrix ... 0.007
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.007
# Factorize (Cholmod) matrix ... 0.007
# Factorize (Cholmod) matrix ... 0.007
# Factorize (Cholmod) matrix ... 0.007
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.005
# Factorize (Cholmod) matrix ... 0.006
# Forward: time: 0.129s
# Response: min = 72.4309 max = 155.567 mean = 101.429
# Reciprocity rms(modelReciprocity) 5.62682%, max: 16.3867%
# 1: Model: min = 42.4946; max = 187.607
# 1: Response: min = 72.7629; max = 147.758
# 1: rms/rrms(data, Response) = 13.0344/16.1361%
# 1: chi^2(data, Response, error, log) = 182.617
# 1: Phi = 31227.5+12.7581*20=31482.7
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(6/6-std::mt): 0:time: 0.053s
# sens sum: median = 1.19429 min = 0.935175 max = 2.13882
# ... 0.055 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 35.0186 max = 213.232
# Using existing primary potentials.
# Factorize (Cholmod) matrix ... 0.009
# Factorize (Cholmod) matrix ... 0.008
# Factorize (Cholmod) matrix ... 0.008
# Factorize (Cholmod) matrix ... 0.007
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.005
# Factorize (Cholmod) matrix ... 0.007
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.007
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.007
# Forward: time: 0.141s
# Response: min = 24.8199 max = 157.554 mean = 93.8194
# Reciprocity rms(modelReciprocity) 12.1269%, max: 47.442%
# 2: LS newModel: min = 35.0186; max = 213.232
# 2: LS newResponse: min = 22.7972; max = 157.181
# 2: rms/rrms(data, LS newResponse) = 5.39449/7.85526%
# 2: chi^2(data, LS newResponse, error, log) = 84.4847
# 2: Phi = 14446.9+19chi² = 13.27 (dPhi = 91.78%) lam: 20.0
# .69*20=14840.7
# Linesearch tau = 0.61
# Calculating response for model: min = 46.1518 max = 202.847
# Using existing primary potentials.
# Factorize (Cholmod) matrix ... 0.013
# Factorize (Cholmod) matrix ... 0.008
# Factorize (Cholmod) matrix ... 0.008
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.011
# Factorize (Cholmod) matrix ... 0.008
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.007
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.007
# Factorize (Cholmod) matrix ... 0.005
# Factorize (Cholmod) matrix ... 0.005
# Forward: time: 0.145s
# Response: min = 46.7285 max = 152.512 mean = 96.4707
# Reciprocity rms(modelReciprocity) 8.00433%, max: 33.5417%
# 2: Model: min = 46.1518; max = 202.847
# 2: Response: min = 45.6009; max = 152.416
# 2: rms/rrms(data, Response) = 3.31832/3.75162%
# 2: chi^2(data, Response, error, log) = 13.2738
# 2: Phi = 2269.82+15.9767*20=2589.35
# --------------------------------------------------------------------------------
# inv.iter 3 ... calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(6/6-std::mt): 0:time: 0.077s
# sens sum: median = 1.20131 min = 0.947775 max = 2.18988
# ... 0.078 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 24.9179 max = 206.223
# Using existing primary potentials.
# Factorize (Cholmod) matrix ... 0.01
# Factorize (Cholmod) matrix ... 0.008
# Factorize (Cholmod) matrix ... 0.009
# Factorize (Cholmod) matrix ... 0.008
# Factorize (Cholmod) matrix ... 0.007
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.005
# Factorize (Cholmod) matrix ... 0.007
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.005
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.005
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.007
# Forward: time: 0.137s
# Found neg. resp (saving).
# 170 -2.53029 -5.7044
# 0 1 19 20
# Response: min = -2.53029 max = 158.128 mean = 88.6484
# Reciprocity rms(modelReciprocity) 26.5103%, max: 83.6459%
# tau = 0. Trying parabolic line search with step length 0.3Calculating response for model: min = 40.595 max = 203.854
# Using existing primary potentials.
# Factorize (Cholmod) matrix ... 0.009
# Factorize (Cholmod) matrix ... 0.007
# Factorize (Cholmod) matrix ... 0.007
# Factorize (Cholmod) matrix ... 0.005
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.008
# Factorize (Cholmod) matrix ... 0.007
# Factorize (Cholmod) matrix ... 0.005
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.005
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.006
# Forward: time: 0.135s
# Response: min = 30.5423 max = 154.188 mean = 94.0229
# Reciprocity rms(modelReciprocity) 11.2473%, max: 44.8896%
# chi² = 13.9 (dPhi = -4.27%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 4 ...  ==> tau = 0.0935764
# 3: LS newModel: min = 24.9179; max = 206.223
# 3: LS newResponse: min = 3.79918; max = 157.665
# 3: rms/rrms(data, LS newResponse) = 12.9787/17.2463%
# 3: chi^2(data, LS newResponse, error, log) = 709.379
# 3: Phi = 121304+21.7403*20=121739
# Linesearch tau = 0.0935764
# Calculating response for model: min = 46.879 max = 203.16
# Using existing primary potentials.
# Factorize (Cholmod) matrix ... 0.011
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.005
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.007
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.005
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.005
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.005
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.006
# Forward: time: 0.131s
# Response: min = 41.6373 max = 153.034 mean = 95.7073
# Reciprocity rms(modelReciprocity) 8.85631%, max: 36.7948%
# 3: Model: min = 46.879; max = 203.16
# 3: Response: min = 40.4505; max = 152.905
# 3: rms/rrms(data, Response) = 2.9386/3.70499%
# 3: chi^2(data, Response, error, log) = 13.8981
# 3: Phi = 2376.57+16.1726*20=2700.02
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(6/6-std::mt): 0:time: 0.056s
# sens sum: median = 1.19389 min = 0.948283 max = 2.19396
# ... 0.056 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 23.8343 max = 205.633
# Using existing primary potentials.
# Factorize (Cholmod) matrix ... 0.009
# Factorize (Cholmod) matrix ... 0.01
# Factorize (Cholmod) matrix ... 0.008
# Factorize (Cholmod) matrix ... 0.01
# Factorize (Cholmod) matrix ... 0.007
# Factorize (Cholmod) matrix ... 0.005
# Factorize (Cholmod) matrix ... 0.007
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.007
# Factorize (Cholmod) matrix ... 0.007
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.007
# Forward: time: 0.15s
# Found neg. resp (saving).
# 170 -4.89836 -7.7849
# 0 1 19 20
# Response: min = -4.89836 max = 158.144 mean = 88.3265
# Reciprocity rms(modelReciprocity) 28.4225%, max: 92.9548%
# chi² = 15.36 (dPhi = -9.31%) lam: 20.0
# ################################################################################
# #                Abort criteria reached: dPhi = -9.31 (< 2.0%)                 #
# ################################################################################
# tau = 0. Trying parabolic line search with step length 0.3Calculating response for model: min = 38.2689 max = 203.899
# Using existing primary potentials.
# Factorize (Cholmod) matrix ... 0.007
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.005
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.013
# Factorize (Cholmod) matrix ... 0.009
# Factorize (Cholmod) matrix ... 0.008
# Factorize (Cholmod) matrix ... 0.007
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.009
# Factorize (Cholmod) matrix ... 0.007
# Factorize (Cholmod) matrix ... 0.005
# Forward: time: 0.144s
# Response: min = 26.5438 max = 154.557 mean = 93.3988
# Reciprocity rms(modelReciprocity) 12.5006%, max: 48.693%
#  ==> tau = 0.022075
#  tau < 0.03 ==> tau = 0.03
# 4: LS newModel: min = 23.8343; max = 205.633
# 4: LS newResponse: min = 6.17521; max = 157.673
# 4: rms/rrms(data, LS newResponse) = 13.5205/17.8111%
# 4: chi^2(data, LS newResponse, error, log) = 643.846
# 4: Phi = 110098+22.4246*20=110546
# Linesearch tau = 0.03
# Calculating response for model: min = 45.9373 max = 203.234
# Using existing primary potentials.
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.008
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.005
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.005
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.007
# Factorize (Cholmod) matrix ... 0.007
# Factorize (Cholmod) matrix ... 0.005
# Factorize (Cholmod) matrix ... 0.006
# Factorize (Cholmod) matrix ... 0.005
# Factorize (Cholmod) matrix ... 0.005
# Forward: time: 0.12s
# Response: min = 40.1269 max = 153.186 mean = 95.4774
# Reciprocity rms(modelReciprocity) 9.1533%, max: 37.8633%
# 4: Model: min = 45.9373; max = 203.234
# 4: Response: min = 38.9252; max = 153.047
# 4: rms/rrms(data, Response) = 2.93337/3.84243%
# 4: chi^2(data, Response, error, log) = 15.3603
# 4: Phi = 2626.61+16.2417*20=2951.44

# %%
simulate_root.display_inverted_img()

# %%
simulate_root.animate_simulation()
# Out:
# Starting Animation......
# <img src="figures/res_mod_dd.gif">
